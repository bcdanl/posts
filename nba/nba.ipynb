# %% [markdown]
# ---
# title: "NBA"
# author: "Byeong-Hak Choe"
# date: "2024-02-15"  # Use the format YYYY-MM-DD
# categories: [python, data-analysis, nba]
# image: "image.jpeg"
# ---

# %%
import pandas as pd
nba = pd.read_csv("https://bcdanl.github.io/data/nfl.csv", parse_dates = ["Birthday"])
nba
# Out:
#                     Name                  Team Position   Birthday   Salary
# 0           Tremon Smith   Philadelphia Eagles       RB 1996-07-20   570000
# 1         Shawn Williams    Cincinnati Bengals       SS 1991-05-13  3500000
# 2            Adam Butler  New England Patriots       DT 1994-04-12   645000
# 3            Derek Wolfe        Denver Broncos       DE 1990-02-24  8000000
# 4              Jake Ryan  Jacksonville Jaguars      OLB 1992-02-27  1000000
# ...                  ...                   ...      ...        ...      ...
# 1650    Bashaud Breeland    Kansas City Chiefs       CB 1992-01-30   805000
# 1651         Craig James   Philadelphia Eagles       CB 1996-04-29   570000
# 1652  Jonotthan Harrison         New York Jets        C 1991-08-25  1500000
# 1653         Chuma Edoga         New York Jets       OT 1997-05-25   495000
# 1654        Tajae Sharpe      Tennessee Titans       WR 1994-12-23  2025000
#
# [1655 rows x 5 columns]

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()
nba
# Out:
#                Name                 Team Position  Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG   9/26/96   1445697
# 1    Christian Wood      Detroit Pistons       PF   9/27/95   1645357
# 2     PJ Washington    Charlotte Hornets       PF   8/23/98   3831840
# 3      Derrick Rose      Detroit Pistons       PG   10/4/88   7317074
# 4     Marial Shayok   Philadelphia 76ers        G   7/26/95     79568
# ..              ...                  ...      ...       ...       ...
# 445   Austin Rivers      Houston Rockets       PG    8/1/92   2174310
# 446     Harry Giles     Sacramento Kings       PF   4/22/98   2578800
# 447     Robin Lopez      Milwaukee Bucks        C    4/1/88   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG    1/4/99   4764960
# 449     Ricky Rubio         Phoenix Suns       PG  10/21/90  16200000
#
# [450 rows x 5 columns]

# %%
nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv",
                  parse_dates = ["Birthday"])
nba
# Out:
#                Name                 Team Position   Birthday      Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697.0
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357.0
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840.0
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074.0
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26         NaN
# ..              ...                  ...      ...        ...         ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310.0
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800.0
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000.0
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960.0
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000.0
#
# [450 rows x 5 columns]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      450 non-null    object
#  1   Team      450 non-null    object
#  2   Position  450 non-null    object
#  3   Birthday  450 non-null    datetime64[ns]
#  4   Salary    449 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 17.7+ KB

# %%
nba.shape
# Out:
# (450, 5)

# %%
nba.dtypes
# Out:
# Name                object
# Team                object
# Position            object
# Birthday    datetime64[ns]
# Salary             float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Birthday', 'Salary'], dtype='object')

# %%
nba.count()
# Out:
# Name        450
# Team        450
# Position    450
# Birthday    450
# Salary      450
# dtype: int64

# %%
nba[['Position']].value_counts()   # Series
# Out:
# Position
# PG          98
# PF          96
# C           88
# SF          76
# SG          74
# G           10
# F            5
# GF           2
# FC           1
# dtype: int64

# %%
nba[['Team']].nunique()
# Out:
# Team    30
# dtype: int64

# %%
nba.nunique()
# Out:
# Name        450
# Team         30
# Position      9
# Birthday    430
# Salary      269
# dtype: int64

# %%
nba[['Team']].nunique()
# Out:
# Team    30
# dtype: int64

# %%
nba[['Team']].value_counts()
# Out:
# Team
# Brooklyn Nets             17
# Utah Jazz                 17
# Philadelphia 76ers        17
# Minnesota Timberwolves    17
# Boston Celtics            16
# Charlotte Hornets         16
# Chicago Bulls             16
# Toronto Raptors           16
# Detroit Pistons           16
# New York Knicks           16
# New Orleans Pelicans      16
# Los Angeles Lakers        16
# Atlanta Hawks             15
# Sacramento Kings          15
# Phoenix Suns              15
# Miami Heat                15
# Memphis Grizzlies         15
# Golden State Warriors     15
# Denver Nuggets            15
# Milwaukee Bucks           14
# Los Angeles Clippers      14
# Houston Rockets           14
# Portland Trail Blazers    14
# San Antonio Spurs         14
# Washington Wizards        14
# Indiana Pacers            13
# Oklahoma City Thunder     13
# Orlando Magic             13
# Dallas Mavericks          13
# Cleveland Cavaliers       13
# dtype: int64

# %%
nba[['Team','Position']].value_counts()   # Series
# Out:
# Team                Position
# Memphis Grizzlies   SF          6
# Washington Wizards  PG          6
# Phoenix Suns        PG          5
# Brooklyn Nets       PF          5
# Chicago Bulls       PG          5
#                                ..
# Sacramento Kings    SF          1
# Philadelphia 76ers  G           1
# San Antonio Spurs   C           1
#                     G           1
# Philadelphia 76ers  FC          1
# Length: 164, dtype: int64

# %%
nba[['Team']].size
# Out:
# 450

# %%
len(nba['Salary'])
# Out:
# 450

# %%
nba.nunique()
# Out:
# Name        450
# Team         30
# Position      9
# Birthday    430
# Salary      269
# dtype: int64

# %%
nba.nunique()
# Out:
# Name        450
# Team         30
# Position      9
# Birthday    430
# Salary      269
# dtype: int64

# %%
type(nba['Salary'].count())
# Out:
# numpy.int64

# %%
nba.count()
# Out:
# Name        450
# Team        450
# Position    450
# Birthday    450
# Salary      449
# dtype: int64

# %%
nba[ ['Team'] ].value_counts()   # DataFrame
# Out:
# Team
# Brooklyn Nets             17
# Utah Jazz                 17
# Philadelphia 76ers        17
# Minnesota Timberwolves    17
# Boston Celtics            16
# Charlotte Hornets         16
# Chicago Bulls             16
# Toronto Raptors           16
# Detroit Pistons           16
# New York Knicks           16
# New Orleans Pelicans      16
# Los Angeles Lakers        16
# Atlanta Hawks             15
# Sacramento Kings          15
# Phoenix Suns              15
# Miami Heat                15
# Memphis Grizzlies         15
# Golden State Warriors     15
# Denver Nuggets            15
# Milwaukee Bucks           14
# Los Angeles Clippers      14
# Houston Rockets           14
# Portland Trail Blazers    14
# San Antonio Spurs         14
# Washington Wizards        14
# Indiana Pacers            13
# Oklahoma City Thunder     13
# Orlando Magic             13
# Dallas Mavericks          13
# Cleveland Cavaliers       13
# dtype: int64

# %%
nba.describe()
# Out:
#              Salary
# count  4.500000e+02
# mean   7.653584e+06
# std    9.288810e+06
# min    7.956800e+04
# 25%    1.618520e+06
# 50%    3.303074e+06
# 75%    1.012957e+07
# max    4.023176e+07

# %%
nba.describe(include = "all")
# Out:
#                 Name                Team Position Birthday        Salary
# count            450                 450      450      450  4.500000e+02
# unique           450                  30        9      430           NaN
# top     Shake Milton  Philadelphia 76ers       PG  9/28/95           NaN
# freq               1                  17       98        3           NaN
# mean             NaN                 NaN      NaN      NaN  7.653584e+06
# std              NaN                 NaN      NaN      NaN  9.288810e+06
# min              NaN                 NaN      NaN      NaN  7.956800e+04
# 25%              NaN                 NaN      NaN      NaN  1.618520e+06
# 50%              NaN                 NaN      NaN      NaN  3.303074e+06
# 75%              NaN                 NaN      NaN      NaN  1.012957e+07
# max              NaN                 NaN      NaN      NaN  4.023176e+07

# %%
nba_player_name = nba['Name']
nba_player_name
# Out:
# 0        Shake Milton
# 1      Christian Wood
# 2       PJ Washington
# 3        Derrick Rose
# 4       Marial Shayok
#             ...
# 445     Austin Rivers
# 446       Harry Giles
# 447       Robin Lopez
# 448     Collin Sexton
# 449       Ricky Rubio
# Name: Name, Length: 450, dtype: object

# %%
nba_player_name_team = nba[ ['Name', 'Team'] ]
nba_player_name_team
# Out:
#                Name                 Team
# 0      Shake Milton   Philadelphia 76ers
# 1    Christian Wood      Detroit Pistons
# 2     PJ Washington    Charlotte Hornets
# 3      Derrick Rose      Detroit Pistons
# 4     Marial Shayok   Philadelphia 76ers
# ..              ...                  ...
# 445   Austin Rivers      Houston Rockets
# 446     Harry Giles     Sacramento Kings
# 447     Robin Lopez      Milwaukee Bucks
# 448   Collin Sexton  Cleveland Cavaliers
# 449     Ricky Rubio         Phoenix Suns
#
# [450 rows x 2 columns]

# %%
nba.sort_values("Name")
# Out:
#                   Name                   Team Position   Birthday    Salary
# 52        Aaron Gordon          Orlando Magic       PF 1995-09-16  19863636
# 101      Aaron Holiday         Indiana Pacers       PG 1996-09-30   2239200
# 437        Abdel Nader  Oklahoma City Thunder       SF 1993-09-25   1618520
# 81         Adam Mokoka          Chicago Bulls        G 1998-07-18     79568
# 399  Admiral Schofield     Washington Wizards       SF 1997-03-30   1000000
# ..                 ...                    ...      ...        ...       ...
# 159        Zach LaVine          Chicago Bulls       PG 1995-03-10  19500000
# 302       Zach Norvell     Los Angeles Lakers       SG 1997-12-09     79568
# 312       Zhaire Smith     Philadelphia 76ers       SG 1999-06-04   3058800
# 137    Zion Williamson   New Orleans Pelicans        F 2000-07-06   9757440
# 248     Zylan Cheatham   New Orleans Pelicans       SF 1995-11-17     79568
#
# [450 rows x 5 columns]

# %%
nba.sort_values(by = "Name")
# Out:
#                   Name                   Team Position   Birthday    Salary
# 52        Aaron Gordon          Orlando Magic       PF 1995-09-16  19863636
# 101      Aaron Holiday         Indiana Pacers       PG 1996-09-30   2239200
# 437        Abdel Nader  Oklahoma City Thunder       SF 1993-09-25   1618520
# 81         Adam Mokoka          Chicago Bulls        G 1998-07-18     79568
# 399  Admiral Schofield     Washington Wizards       SF 1997-03-30   1000000
# ..                 ...                    ...      ...        ...       ...
# 159        Zach LaVine          Chicago Bulls       PG 1995-03-10  19500000
# 302       Zach Norvell     Los Angeles Lakers       SG 1997-12-09     79568
# 312       Zhaire Smith     Philadelphia 76ers       SG 1999-06-04   3058800
# 137    Zion Williamson   New Orleans Pelicans        F 2000-07-06   9757440
# 248     Zylan Cheatham   New Orleans Pelicans       SF 1995-11-17     79568
#
# [450 rows x 5 columns]

# %%
nba.sort_values(by = ["Name"])
# Out:
#                   Name                   Team Position   Birthday    Salary
# 52        Aaron Gordon          Orlando Magic       PF 1995-09-16  19863636
# 101      Aaron Holiday         Indiana Pacers       PG 1996-09-30   2239200
# 437        Abdel Nader  Oklahoma City Thunder       SF 1993-09-25   1618520
# 81         Adam Mokoka          Chicago Bulls        G 1998-07-18     79568
# 399  Admiral Schofield     Washington Wizards       SF 1997-03-30   1000000
# ..                 ...                    ...      ...        ...       ...
# 159        Zach LaVine          Chicago Bulls       PG 1995-03-10  19500000
# 302       Zach Norvell     Los Angeles Lakers       SG 1997-12-09     79568
# 312       Zhaire Smith     Philadelphia 76ers       SG 1999-06-04   3058800
# 137    Zion Williamson   New Orleans Pelicans        F 2000-07-06   9757440
# 248     Zylan Cheatham   New Orleans Pelicans       SF 1995-11-17     79568
#
# [450 rows x 5 columns]

# %%
nba.sort_values(["Name"])
# Out:
#                   Name                   Team Position   Birthday    Salary
# 52        Aaron Gordon          Orlando Magic       PF 1995-09-16  19863636
# 101      Aaron Holiday         Indiana Pacers       PG 1996-09-30   2239200
# 437        Abdel Nader  Oklahoma City Thunder       SF 1993-09-25   1618520
# 81         Adam Mokoka          Chicago Bulls        G 1998-07-18     79568
# 399  Admiral Schofield     Washington Wizards       SF 1997-03-30   1000000
# ..                 ...                    ...      ...        ...       ...
# 159        Zach LaVine          Chicago Bulls       PG 1995-03-10  19500000
# 302       Zach Norvell     Los Angeles Lakers       SG 1997-12-09     79568
# 312       Zhaire Smith     Philadelphia 76ers       SG 1999-06-04   3058800
# 137    Zion Williamson   New Orleans Pelicans        F 2000-07-06   9757440
# 248     Zylan Cheatham   New Orleans Pelicans       SF 1995-11-17     79568
#
# [450 rows x 5 columns]

# %%
nba.sort_values(["Name"], ascending = False)
# Out:
#                   Name                   Team Position   Birthday    Salary
# 248     Zylan Cheatham   New Orleans Pelicans       SF 1995-11-17     79568
# 137    Zion Williamson   New Orleans Pelicans        F 2000-07-06   9757440
# 312       Zhaire Smith     Philadelphia 76ers       SG 1999-06-04   3058800
# 302       Zach Norvell     Los Angeles Lakers       SG 1997-12-09     79568
# 159        Zach LaVine          Chicago Bulls       PG 1995-03-10  19500000
# ..                 ...                    ...      ...        ...       ...
# 399  Admiral Schofield     Washington Wizards       SF 1997-03-30   1000000
# 81         Adam Mokoka          Chicago Bulls        G 1998-07-18     79568
# 437        Abdel Nader  Oklahoma City Thunder       SF 1993-09-25   1618520
# 101      Aaron Holiday         Indiana Pacers       PG 1996-09-30   2239200
# 52        Aaron Gordon          Orlando Magic       PF 1995-09-16  19863636
#
# [450 rows x 5 columns]

# %%
nba.nsmallest(5, 'Salary')
# Out:
#                Name                    Team Position   Birthday  Salary
# 4     Marial Shayok      Philadelphia 76ers        G 1995-07-26   79568
# 12     Norvel Pelle      Philadelphia 76ers       FC 1993-02-03   79568
# 24     Jaylen Hoard  Portland Trail Blazers       SF 1999-03-30   79568
# 25       Tyler Cook     Cleveland Cavaliers       PF 1997-09-23   79568
# 31  Michael Frazier         Houston Rockets        G 1994-03-08   79568

# %%
nba.nsmallest(5, 'Salary', keep = "all")
# Out:
#                        Name                    Team Position   Birthday  \
# 4             Marial Shayok      Philadelphia 76ers        G 1995-07-26
# 12             Norvel Pelle      Philadelphia 76ers       FC 1993-02-03
# 24             Jaylen Hoard  Portland Trail Blazers       SF 1999-03-30
# 25               Tyler Cook     Cleveland Cavaliers       PF 1997-09-23
# 31          Michael Frazier         Houston Rockets        G 1994-03-08
# 37                Dean Wade     Cleveland Cavaliers       PF 1996-11-20
# 45            Robert Franks       Charlotte Hornets        F 1996-12-18
# 73    Justin Wright-Foreman               Utah Jazz        G 1997-10-27
# 81              Adam Mokoka           Chicago Bulls        G 1998-07-18
# 97              Chris Silva              Miami Heat       PF 1996-09-19
# 100             Brian Bowen          Indiana Pacers       SG 1998-10-02
# 105            John Konchar       Memphis Grizzlies       SG 1996-03-22
# ...

# %%
nba.nlargest(4, 'Salary')
# Out:
#                   Name                   Team Position   Birthday    Salary
# 205      Stephen Curry  Golden State Warriors       PG 1988-03-14  40231758
# 38          Chris Paul  Oklahoma City Thunder       PG 1985-05-06  38506482
# 219  Russell Westbrook        Houston Rockets       PG 1988-11-12  38506482
# 251          John Wall     Washington Wizards       PG 1990-09-06  38199000

# %%
nba.nlargest(4, 'Salary', keep = "all")
# Out:
#                   Name                   Team Position   Birthday    Salary
# 205      Stephen Curry  Golden State Warriors       PG 1988-03-14  40231758
# 38          Chris Paul  Oklahoma City Thunder       PG 1985-05-06  38506482
# 219  Russell Westbrook        Houston Rockets       PG 1988-11-12  38506482
# 251          John Wall     Washington Wizards       PG 1990-09-06  38199000
# 264       James Harden        Houston Rockets       PG 1989-08-26  38199000

# %%
(
    nba
    .sort_values(['Salary'], ascending=False)
    .head(4)
)
# Out:
#                   Name                   Team Position   Birthday    Salary
# 205      Stephen Curry  Golden State Warriors       PG 1988-03-14  40231758
# 219  Russell Westbrook        Houston Rockets       PG 1988-11-12  38506482
# 38          Chris Paul  Oklahoma City Thunder       PG 1985-05-06  38506482
# 251          John Wall     Washington Wizards       PG 1990-09-06  38199000

# %%
df = nba.sort_values(["Salary"])
df.tail(5)
# Out:
#                   Name                   Team Position   Birthday    Salary
# 251          John Wall     Washington Wizards       PG 1990-09-06  38199000
# 264       James Harden        Houston Rockets       PG 1989-08-26  38199000
# 38          Chris Paul  Oklahoma City Thunder       PG 1985-05-06  38506482
# 219  Russell Westbrook        Houston Rockets       PG 1988-11-12  38506482
# 205      Stephen Curry  Golden State Warriors       PG 1988-03-14  40231758

# %%
nba[["Birthday", "Salary"]].head()
# Out:
#   Birthday   Salary
# 0  9/26/96  1445697
# 1  9/27/95  1645357
# 2  8/23/98  3831840
# 3  10/4/88  7317074
# 4  7/26/95    79568

# %%
nba.sort_values(by = ["Team", "Name"])
# Out:
#                 Name                Team Position   Birthday      Salary
# 359         Alex Len       Atlanta Hawks        C 1993-06-16   4160000.0
# 167     Allen Crabbe       Atlanta Hawks       SG 1992-04-09  18500000.0
# 276  Brandon Goodwin       Atlanta Hawks       PG 1995-10-02     79568.0
# 438   Bruno Fernando       Atlanta Hawks        C 1998-08-15   1400000.0
# 194      Cam Reddish       Atlanta Hawks       SF 1999-09-01   4245720.0
# ..               ...                 ...      ...        ...         ...
# 418     Jordan McRae  Washington Wizards       PG 1991-03-28   1645357.0
# 273  Justin Robinson  Washington Wizards       PG 1997-10-12    898310.0
# 428    Moritz Wagner  Washington Wizards        C 1997-04-26   2063520.0
# 21     Rui Hachimura  Washington Wizards       PF 1998-02-08   4469160.0
# 36     Thomas Bryant  Washington Wizards        C 1997-07-31   8000000.0
#
# [450 rows x 5 columns]

# %%
nba.sort_values(by = ["Team", "Name"], ascending= [False, True])
# Out:
#                   Name                Team Position   Birthday      Salary
# 399  Admiral Schofield  Washington Wizards       SF 1997-03-30   1000000.0
# 35        Bradley Beal  Washington Wizards       SG 1993-06-28  27093018.0
# 353      Chris Chiozza  Washington Wizards       PG 1995-11-21     79568.0
# 226      Davis Bertans  Washington Wizards       PF 1992-11-12   7000000.0
# 283   Garrison Mathews  Washington Wizards       SG 1996-10-24     79568.0
# ..                 ...                 ...      ...        ...         ...
# 339      Jabari Parker       Atlanta Hawks       PF 1995-03-15   6500000.0
# 84        John Collins       Atlanta Hawks       PF 1997-09-23   2686560.0
# 20       Kevin Huerter       Atlanta Hawks       SG 1998-08-27   2636280.0
# 290     Tyrone Wallace       Atlanta Hawks       PG 1994-06-10   1620564.0
# 98        Vince Carter       Atlanta Hawks       PF 1977-01-26   2564753.0
#
# [450 rows x 5 columns]

# %%
nba.sort_values(["Team", "Name"])
# Out:
#                 Name                Team Position   Birthday      Salary
# 359         Alex Len       Atlanta Hawks        C 1993-06-16   4160000.0
# 167     Allen Crabbe       Atlanta Hawks       SG 1992-04-09  18500000.0
# 276  Brandon Goodwin       Atlanta Hawks       PG 1995-10-02     79568.0
# 438   Bruno Fernando       Atlanta Hawks        C 1998-08-15   1400000.0
# 194      Cam Reddish       Atlanta Hawks       SF 1999-09-01   4245720.0
# ..               ...                 ...      ...        ...         ...
# 418     Jordan McRae  Washington Wizards       PG 1991-03-28   1645357.0
# 273  Justin Robinson  Washington Wizards       PG 1997-10-12    898310.0
# 428    Moritz Wagner  Washington Wizards        C 1997-04-26   2063520.0
# 21     Rui Hachimura  Washington Wizards       PF 1998-02-08   4469160.0
# 36     Thomas Bryant  Washington Wizards        C 1997-07-31   8000000.0
#
# [450 rows x 5 columns]

# %%
nba.sort_values(['Team', 'Salary'], ascending=[True, False])
# Out:
#                   Name                Team Position   Birthday      Salary
# 111   Chandler Parsons       Atlanta Hawks       SF 1988-10-25  25102512.0
# 28         Evan Turner       Atlanta Hawks       PG 1988-10-27  18606556.0
# 167       Allen Crabbe       Atlanta Hawks       SG 1992-04-09  18500000.0
# 213    De'Andre Hunter       Atlanta Hawks       SF 1997-12-02   7068360.0
# 339      Jabari Parker       Atlanta Hawks       PF 1995-03-15   6500000.0
# ..                 ...                 ...      ...        ...         ...
# 80         Isaac Bonga  Washington Wizards       PG 1999-11-08   1416852.0
# 399  Admiral Schofield  Washington Wizards       SF 1997-03-30   1000000.0
# 273    Justin Robinson  Washington Wizards       PG 1997-10-12    898310.0
# 283   Garrison Mathews  Washington Wizards       SG 1996-10-24     79568.0
# 353      Chris Chiozza  Washington Wizards       PG 1995-11-21     79568.0
#
# [450 rows x 5 columns]

# %%
nba.sort_index(axis = "columns")
# Out:
#       Birthday            Name Position      Salary                 Team
# 0   1996-09-26    Shake Milton       SG   1445697.0   Philadelphia 76ers
# 1   1995-09-27  Christian Wood       PF   1645357.0      Detroit Pistons
# 2   1998-08-23   PJ Washington       PF   3831840.0    Charlotte Hornets
# 3   1988-10-04    Derrick Rose       PG   7317074.0      Detroit Pistons
# 4   1995-07-26   Marial Shayok        G         NaN   Philadelphia 76ers
# ..         ...             ...      ...         ...                  ...
# 445 1992-08-01   Austin Rivers       PG   2174310.0      Houston Rockets
# 446 1998-04-22     Harry Giles       PF   2578800.0     Sacramento Kings
# 447 1988-04-01     Robin Lopez        C   4767000.0      Milwaukee Bucks
# 448 1999-01-04   Collin Sexton       PG   4764960.0  Cleveland Cavaliers
# 449 1990-10-21     Ricky Rubio       PG  16200000.0         Phoenix Suns
#
# [450 rows x 5 columns]

# %%
nba.sort_index(axis = "columns")
# Out:
#       Birthday            Name Position      Salary                 Team
# 0   1996-09-26    Shake Milton       SG   1445697.0   Philadelphia 76ers
# 1   1995-09-27  Christian Wood       PF   1645357.0      Detroit Pistons
# 2   1998-08-23   PJ Washington       PF   3831840.0    Charlotte Hornets
# 3   1988-10-04    Derrick Rose       PG   7317074.0      Detroit Pistons
# 4   1995-07-26   Marial Shayok        G         NaN   Philadelphia 76ers
# ..         ...             ...      ...         ...                  ...
# 445 1992-08-01   Austin Rivers       PG   2174310.0      Houston Rockets
# 446 1998-04-22     Harry Giles       PF   2578800.0     Sacramento Kings
# 447 1988-04-01     Robin Lopez        C   4767000.0      Milwaukee Bucks
# 448 1999-01-04   Collin Sexton       PG   4764960.0  Cleveland Cavaliers
# 449 1990-10-21     Ricky Rubio       PG  16200000.0         Phoenix Suns
#
# [450 rows x 5 columns]

# %%
nba2 = nba.set_index(keys = "Name")
nba2
# Out:
#                                Team Position   Birthday      Salary
# Name
# Shake Milton     Philadelphia 76ers       SG 1996-09-26   1445697.0
# Christian Wood      Detroit Pistons       PF 1995-09-27   1645357.0
# PJ Washington     Charlotte Hornets       PF 1998-08-23   3831840.0
# Derrick Rose        Detroit Pistons       PG 1988-10-04   7317074.0
# Marial Shayok    Philadelphia 76ers        G 1995-07-26         NaN
# ...                             ...      ...        ...         ...
# Austin Rivers       Houston Rockets       PG 1992-08-01   2174310.0
# Harry Giles        Sacramento Kings       PF 1998-04-22   2578800.0
# Robin Lopez         Milwaukee Bucks        C 1988-04-01   4767000.0
# Collin Sexton   Cleveland Cavaliers       PG 1999-01-04   4764960.0
# Ricky Rubio            Phoenix Suns       PG 1990-10-21  16200000.0
#
# [450 rows x 4 columns]

# %%
nba2.reset_index(inplace=True)

# %%
nba2
# Out:
#                Name                 Team Position   Birthday      Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697.0
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357.0
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840.0
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074.0
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26         NaN
# ..              ...                  ...      ...        ...         ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310.0
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800.0
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000.0
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960.0
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000.0
#
# [450 rows x 5 columns]

# %%
nba.loc["LeBron James"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-19673fcea334> in <cell line: 1>()
# ----> 1 nba.loc["LeBron James"]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1310         # fall thru to straight lookup
#    1311         self._validate_key(key, axis)
# -> 1312         return self._get_label(key, axis=axis)
#    1313
#    1314     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ...

# %%
nba.loc[1]
# Out:
# Name             Christian Wood
# Team            Detroit Pistons
# Position                     PF
# Birthday    1995-09-27 00:00:00
# Salary                1645357.0
# Name: 1, dtype: object

# %%
nba.loc[0]

# %%
nba.set_index("Name", inplace = True)

# %%
(
    nba
    .sort_index()
    .loc["Otto Porter":"Patrick Beverley"]
)
# Out:
#                                   Team Position   Birthday      Salary
# Name
# Otto Porter              Chicago Bulls       SF 1993-06-03  27250576.0
# PJ Dozier               Denver Nuggets       PG 1996-10-25     79568.0
# PJ Washington        Charlotte Hornets       PF 1998-08-23   3831840.0
# Pascal Siakam          Toronto Raptors       PF 1994-04-02   2351838.0
# Pat Connaughton        Milwaukee Bucks       SG 1993-01-06   1723050.0
# Patrick Beverley  Los Angeles Clippers       PG 1988-07-12  12345680.0

# %%
nba.loc[
    ["Russell Westbrook", "Anthony Davis"],
     ["Team", "Salary"]
]
# Out:
#                                  Team      Salary
# Name
# Russell Westbrook     Houston Rockets  38506482.0
# Anthony Davis      Los Angeles Lakers  27093019.0

# %%
nba.loc[
     "James Harden",
      ["Position", "Birthday"]
]

# %%
nba.loc[
    "LeBron James",
    "Team"
]

# %%
nba.loc[
    "Joel Embiid",
    "Position":"Salary"
]
# Out:
# Position                      C
# Birthday    1994-03-16 00:00:00
# Salary               27504630.0
# Name: Joel Embiid, dtype: object

# %%
nba.iloc[
    100:104,
    :3
]
# Out:
#                              Team Position   Birthday
# Name
# Brian Bowen        Indiana Pacers       SG 1998-10-02
# Aaron Holiday      Indiana Pacers       PG 1996-09-30
# Troy Daniels   Los Angeles Lakers       SG 1991-07-15
# Buddy Hield      Sacramento Kings       SG 1992-12-17

# %%
nba.iloc[
    57,
    3
]

# %%
nba.columns = ["Team", "Position", "Date of Birth", "Income"]

# %%
nba.rename( columns = { "Date of Birth": "Birthday" } )
# Out:
#                                Team Position   Birthday      Income
# Name
# Shake Milton     Philadelphia 76ers       SG 1996-09-26   1445697.0
# Christian Wood      Detroit Pistons       PF 1995-09-27   1645357.0
# PJ Washington     Charlotte Hornets       PF 1998-08-23   3831840.0
# Derrick Rose        Detroit Pistons       PG 1988-10-04   7317074.0
# Marial Shayok    Philadelphia 76ers        G 1995-07-26         NaN
# ...                             ...      ...        ...         ...
# Austin Rivers       Houston Rockets       PG 1992-08-01   2174310.0
# Harry Giles        Sacramento Kings       PF 1998-04-22   2578800.0
# Robin Lopez         Milwaukee Bucks        C 1988-04-01   4767000.0
# Collin Sexton   Cleveland Cavaliers       PG 1999-01-04   4764960.0
# Ricky Rubio            Phoenix Suns       PG 1990-10-21  16200000.0
#
# [450 rows x 4 columns]

# %%
nba = nba.rename(
    index = { "LeBron James": "LeBron Raymone James" }
)

nba.loc["LeBron James"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LeBron James'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
nba.set_index("Team").head()
# Out:
#                    Position Date of Birth     Income
# Team
# Philadelphia 76ers       SG    1996-09-26  1445697.0
# Detroit Pistons          PF    1995-09-27  1645357.0
# Charlotte Hornets        PF    1998-08-23  3831840.0
# Detroit Pistons          PG    1988-10-04  7317074.0
# Philadelphia 76ers        G    1995-07-26        NaN
